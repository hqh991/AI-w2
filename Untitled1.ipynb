# %%
value1 = int(input("Nhap vao so thu 1:  "))
value2 = int(input("Nhap vao so thu 2:  "))
print("Ket qua la:",value1 + value2)
# Out:
# Nhap vao so thu 1:  2
# Nhap vao so thu 2:  6
# Ket qua la: 8

# %%
with open('text.txt', mode='w') as accounts:
  accounts.write('201461 Nguyen Van A      9.0 \n')
  accounts.write('201462 Nguyen Van B      9.0 \n')
  accounts.write('201463 Nguyen Van C      8.0 \n')
  accounts.write('201464 Nguyen Van D      8.0 \n')
  accounts.write('201465 Nguyen Van E      8.0 \n')
  accounts.write('201466 Nguyen Van F      8.0 \n')

# %%
with open('text1.txt', mode='r') as accounts: 
  print(f'{"MSSV":<10}{"Name":<20}{"Score":>4}')
  for record in accounts: 
    mssv,name,score=record.split()
    print(f'{mssv:<10}{name:<20}{score:>4}')
# Out:
# MSSV      Name                Score

# %%
import pandas as pd
ulr = 'Text4.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(10) 
dataframe.iloc[:4]
# Out:
#     MSSV          Name   Khoa Faculty   Score
# 0  201461  Nguyen Van A    20      CKM      10
# 1  201462  Nguyen Van B    20      CKM      10
# 2  201463  Nguyen Van C    20      CKM      10
# 3  201464  Nguyen Van D    20      CKM      10

# %%
import pandas as pd
ulr = 'Text4.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(10) 
dataframe.iloc[4]

# %%
import pandas as pd
ulr = 'Text4.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(20)

# %%
frame = dataframe.set_index(dataframe['Name '])
frame.loc['Nguyen Van A']
# Out:
# MSSV              201461
# Name        Nguyen Van A
# Khoa                  20
# Faculty              CKM
# Score                 10
# Name: Nguyen Van A, dtype: object

# %%
dataframe[dataframe['Faculty ']=='CKM'].head(5)
# Out:
#     MSSV          Name   Khoa Faculty   Score
# 0  201461  Nguyen Van A    20      CKM      10
# 1  201462  Nguyen Van B    20      CKM      10
# 2  201463  Nguyen Van C    20      CKM      10
# 3  201464  Nguyen Van D    20      CKM      10
# 4  201465  Nguyen Van E    20      CKM      10

# %%
dataframe[(dataframe['Faculty ']=='CKM')&(dataframe['Khoa']==20)]
# Out:
#      MSSV          Name   Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 1   201462  Nguyen Van B    20      CKM      10
# 2   201463  Nguyen Van C    20      CKM      10
# 3   201464  Nguyen Van D    20      CKM      10
# 4   201465  Nguyen Van E    20      CKM      10
# 5   201466  Nguyen Van H    20      CKM      10
# 6   201467  Nguyen Van G    20      CKM      10
# 7   201468  Nguyen Van F    20      CKM      10
# 8   201469  Nguyen Van I    20      CKM      10
# 9   201469  Nguyen Van J    20      CKM      10
# 10  201469  Nguyen Van K    20      CKM      10
# 11  201469  Nguyen Van L    20      CKM      10
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM      10
# 14  201469  Nguyen Van O    20      CKM      10
# 15  201469  Nguyen Van P    20      CKM      10
# 16  201469  Nguyen Van Q    20      CKM      10
# 17  201469  Nguyen Van R    20      CKM      10
# 18  201469  Nguyen Van S    20      CKM      10
# ...

# %%
import pandas as pd
ulr = 'Text6.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(20)
# Out:
#      MSSV           Name  Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 1   201462  Nguyen Van B    22      CKM       4
# 2   201463  Nguyen Van C    21      CKM       5
# 3   201464  Nguyen Van D    19      CKM       7
# 4   201465  Nguyen Van E    20      CKM       3
# 5   201466  Nguyen Van H    20      CKM       8
# 6   201467  Nguyen Van G    20      CKM       9
# 7   201468  Nguyen Van F    20      CKM       9
# 8   201469  Nguyen Van I    20      CKM       6
# 9   201469  Nguyen Van J    21      CKM       7
# 10  201469  Nguyen Van K    20      CKM       8
# 11  201469  Nguyen Van L    20      CKM       4
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM       8
# 14  201469  Nguyen Van O    20      CKM       8
# 15  201469  Nguyen Van P    22      CKM       9
# 16  201469  Nguyen Van Q    21      CKM       7
# 17  201469  Nguyen Van R    20      CKM       5
# 18  201469  Nguyen Van S    22      CKM       7
# ...

# %%
frame = dataframe.set_index(dataframe['Name'])
frame.loc['Nguyen Van E']
# Out:
# MSSV              201465
# Name        Nguyen Van E
# Khoa                  20
# Faculty              CKM
# Score                  3
# Name: Nguyen Van E, dtype: object

# %%
dataframe[dataframe['Faculty ']=='CKM'].head(5)
# Out:
#     MSSV           Name  Khoa Faculty   Score
# 0  201461  Nguyen Van A    20      CKM      10
# 1  201462  Nguyen Van B    22      CKM       4
# 2  201463  Nguyen Van C    21      CKM       5
# 3  201464  Nguyen Van D    19      CKM       7
# 4  201465  Nguyen Van E    20      CKM       3

# %%
dataframe[(dataframe['Faculty ']=='CKM')&(dataframe['Khoa']==20)]
# Out:
#      MSSV           Name  Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 4   201465  Nguyen Van E    20      CKM       3
# 5   201466  Nguyen Van H    20      CKM       8
# 6   201467  Nguyen Van G    20      CKM       9
# 7   201468  Nguyen Van F    20      CKM       9
# 8   201469  Nguyen Van I    20      CKM       6
# 10  201469  Nguyen Van K    20      CKM       8
# 11  201469  Nguyen Van L    20      CKM       4
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM       8
# 14  201469  Nguyen Van O    20      CKM       8
# 17  201469  Nguyen Van R    20      CKM       5
# 19  201469  Nguyen Van T    20      CKM      10

# %%
dataframe[(dataframe['Faculty ']=='CKM')&(dataframe['Score ']>5)]
# Out:
#      MSSV           Name  Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 3   201464  Nguyen Van D    19      CKM       7
# 5   201466  Nguyen Van H    20      CKM       8
# 6   201467  Nguyen Van G    20      CKM       9
# 7   201468  Nguyen Van F    20      CKM       9
# 8   201469  Nguyen Van I    20      CKM       6
# 9   201469  Nguyen Van J    21      CKM       7
# 10  201469  Nguyen Van K    20      CKM       8
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM       8
# 14  201469  Nguyen Van O    20      CKM       8
# 15  201469  Nguyen Van P    22      CKM       9
# 16  201469  Nguyen Van Q    21      CKM       7
# 18  201469  Nguyen Van S    22      CKM       7
# 19  201469  Nguyen Van T    20      CKM      10

# %%
dataframe['Score '].min()
# Out:
# 3

# %%
dataframe['Score '].max()
# Out:
# 10

# %%
dataframe['Score '].sum()
# Out:
# 144

# %%
dataframe['Score '].count()
# Out:
# 20

# %%
dataframe['Score '].unique()
# Out:
# array([10,  4,  5,  7,  3,  8,  9,  6])

# %%
dataframe.drop('Faculty ',axis=1).head(20)

# %%
import pandas as pd
ulr = 'Text6.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(20)

# %%
dataframe.drop(['Khoa','Faculty '],axis=1).head(20)

# %%
import pandas as pd
ulr = 'Text6.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(20)

# %%
dataframe.drop(dataframe.columns[2:4],axis=1).head(20)
# Out:
#      MSSV           Name  Score
# 0   201461  Nguyen Van A      10
# 1   201462  Nguyen Van B       4
# 2   201463  Nguyen Van C       5
# 3   201464  Nguyen Van D       7
# 4   201465  Nguyen Van E       3
# 5   201466  Nguyen Van H       8
# 6   201467  Nguyen Van G       9
# 7   201468  Nguyen Van F       9
# 8   201469  Nguyen Van I       6
# 9   201469  Nguyen Van J       7
# 10  201469  Nguyen Van K       8
# 11  201469  Nguyen Van L       4
# 12  201469  Nguyen Van M      10
# 13  201469  Nguyen Van N       8
# 14  201469  Nguyen Van O       8
# 15  201469  Nguyen Van P       9
# 16  201469  Nguyen Van Q       7
# 17  201469  Nguyen Van R       5
# 18  201469  Nguyen Van S       7
# 19  201469  Nguyen Van T      10

# %%
import pandas as pd
ulr = 'Text6.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(20)
# Out:
#      MSSV           Name  Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 1   201462  Nguyen Van B    22      CKM       4
# 2   201463  Nguyen Van C    21      CKM       5
# 3   201464  Nguyen Van D    19      CKM       7
# 4   201465  Nguyen Van E    20      CKM       3
# 5   201466  Nguyen Van H    20      CKM       8
# 6   201467  Nguyen Van G    20      CKM       9
# 7   201468  Nguyen Van F    20      CKM       9
# 8   201469  Nguyen Van I    20      CKM       6
# 9   201469  Nguyen Van J    21      CKM       7
# 10  201469  Nguyen Van K    20      CKM       8
# 11  201469  Nguyen Van L    20      CKM       4
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM       8
# 14  201469  Nguyen Van O    20      CKM       8
# 15  201469  Nguyen Van P    22      CKM       9
# 16  201469  Nguyen Van Q    21      CKM       7
# 17  201469  Nguyen Van R    20      CKM       5
# 18  201469  Nguyen Van S    22      CKM       7
# ...

# %%
dataframe[dataframe['Khoa']!=19].head(20)
# Out:
#      MSSV           Name  Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 1   201462  Nguyen Van B    22      CKM       4
# 2   201463  Nguyen Van C    21      CKM       5
# 4   201465  Nguyen Van E    20      CKM       3
# 5   201466  Nguyen Van H    20      CKM       8
# 6   201467  Nguyen Van G    20      CKM       9
# 7   201468  Nguyen Van F    20      CKM       9
# 8   201469  Nguyen Van I    20      CKM       6
# 9   201469  Nguyen Van J    21      CKM       7
# 10  201469  Nguyen Van K    20      CKM       8
# 11  201469  Nguyen Van L    20      CKM       4
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM       8
# 14  201469  Nguyen Van O    20      CKM       8
# 15  201469  Nguyen Van P    22      CKM       9
# 16  201469  Nguyen Van Q    21      CKM       7
# 17  201469  Nguyen Van R    20      CKM       5
# 18  201469  Nguyen Van S    22      CKM       7
# 19  201469  Nguyen Van T    20      CKM      10

# %%
import pandas as pd
ulr = 'Text6.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(20)
# Out:
#      MSSV           Name  Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 1   201462  Nguyen Van B    22      CKM       4
# 2   201463  Nguyen Van C    21      CKM       5
# 3   201464  Nguyen Van D    19      CKM       7
# 4   201465  Nguyen Van E    20      CKM       3
# 5   201466  Nguyen Van H    20      CKM       8
# 6   201467  Nguyen Van G    20      CKM       9
# 7   201468  Nguyen Van F    20      CKM       9
# 8   201469  Nguyen Van I    20      CKM       6
# 9   201469  Nguyen Van J    21      CKM       7
# 10  201469  Nguyen Van K    20      CKM       8
# 11  201469  Nguyen Van L    20      CKM       4
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM       8
# 14  201469  Nguyen Van O    20      CKM       8
# 15  201469  Nguyen Van P    22      CKM       9
# 16  201469  Nguyen Van Q    21      CKM       7
# 17  201469  Nguyen Van R    20      CKM       5
# 18  201469  Nguyen Van S    22      CKM       7
# ...

# %%
dataframe[dataframe['Faculty ']!='CKM'].head(20)
# Out:
# Empty DataFrame
# Columns: [MSSV , Name, Khoa, Faculty , Score ]
# Index: []

# %%
dataframe[dataframe.index!=4].head(20)
# Out:
#      MSSV           Name  Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 1   201462  Nguyen Van B    22      CKM       4
# 2   201463  Nguyen Van C    21      CKM       5
# 3   201464  Nguyen Van D    19      CKM       7
# 5   201466  Nguyen Van H    20      CKM       8
# 6   201467  Nguyen Van G    20      CKM       9
# 7   201468  Nguyen Van F    20      CKM       9
# 8   201469  Nguyen Van I    20      CKM       6
# 9   201469  Nguyen Van J    21      CKM       7
# 10  201469  Nguyen Van K    20      CKM       8
# 11  201469  Nguyen Van L    20      CKM       4
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM       8
# 14  201469  Nguyen Van O    20      CKM       8
# 15  201469  Nguyen Van P    22      CKM       9
# 16  201469  Nguyen Van Q    21      CKM       7
# 17  201469  Nguyen Van R    20      CKM       5
# 18  201469  Nguyen Van S    22      CKM       7
# 19  201469  Nguyen Van T    20      CKM      10

# %%
import pandas as pd
ulr = 'Text6.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(20)
# Out:
#      MSSV           Name  Khoa Faculty   Score
# 0   201461  Nguyen Van A    20      CKM      10
# 1   201462  Nguyen Van B    22      CKM       4
# 2   201463  Nguyen Van C    21      CKM       5
# 3   201464  Nguyen Van D    19      CKM       7
# 4   201465  Nguyen Van E    20      CKM       3
# 5   201466  Nguyen Van H    20      CKM       8
# 6   201467  Nguyen Van G    20      CKM       9
# 7   201468  Nguyen Van F    20      CKM       9
# 8   201469  Nguyen Van I    20      CKM       6
# 9   201469  Nguyen Van J    21      CKM       7
# 10  201469  Nguyen Van K    20      CKM       8
# 11  201469  Nguyen Van L    20      CKM       4
# 12  201469  Nguyen Van M    20      CKM      10
# 13  201469  Nguyen Van N    20      CKM       8
# 14  201469  Nguyen Van O    20      CKM       8
# 15  201469  Nguyen Van P    22      CKM       9
# 16  201469  Nguyen Van Q    21      CKM       7
# 17  201469  Nguyen Van R    20      CKM       5
# 18  201469  Nguyen Van S    22      CKM       7
# ...

# %%
dataframe.groupby('Score ').count()
# Out:
#         MSSV   Name  Khoa  Faculty
# Score
# 3           1     1     1         1
# 4           2     2     2         2
# 5           2     2     2         2
# 6           1     1     1         1
# 7           4     4     4         4
# 8           4     4     4         4
# 9           3     3     3         3
# 10          3     3     3         3

# %%
import numpy as np 
import pandas as pd

time = pd.date_range('01/01/2023',periods = 100000, freq = '30s')
dataframe = pd.DataFrame(index = time)
dataframe['Acess_Amount'] = np.random.randint(1,10,100000)
dataframe.resample('w').sum()
# Out:
#             Acess_Amount
# 2023-01-01         14462
# 2023-01-08        100917
# 2023-01-15        100152
# 2023-01-22        100426
# 2023-01-29        100420
# 2023-02-05         82743

# %%
import pandas as pd 
url ='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
import pandas as pd
ulr = 'Text6.csv'
dataframe = pd.read_csv(ulr)
dataframe.head(10)
# Out:
#     MSSV           Name  Khoa Faculty   Score
# 0  201461  Nguyen Van A    20      CKM      10
# 1  201462  Nguyen Van B    22      CKM       4
# 2  201463  Nguyen Van C    21      CKM       5
# 3  201464  Nguyen Van D    19      CKM       7
# 4  201465  Nguyen Van E    20      CKM       3
# 5  201466  Nguyen Van H    20      CKM       8
# 6  201467  Nguyen Van G    20      CKM       9
# 7  201468  Nguyen Van F    20      CKM       9
# 8  201469  Nguyen Van I    20      CKM       6
# 9  201469  Nguyen Van J    21      CKM       7

# %%
import pandas as pd 
url ='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
data[data['City']=='Nagano'].head(50)
# Out:
#       Year    City       Sport       Discipline  NOC  \
# 1620  1998  Nagano      Skiing    Alpine Skiing  AUS
# 1621  1998  Nagano        Luge             Luge  AUT
# 1622  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1623  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1624  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1625  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1626  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1627  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1628  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1629  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1630  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1631  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1632  1998  Nagano      Skiing    Alpine Skiing  AUT
# 1633  1998  Nagano      Skiing  Cross Country S  AUT
# 1634  1998  Nagano      Skiing  Cross Country S  AUT
# 1635  1998  Nagano      Skiing      Ski Jumping  AUT
# 1636  1998  Nagano      Skiing      Ski Jumping  AUT
# ...

# %%
data[data['Medal']=='Gold'].head(5)
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
# 7  1924  Chamonix     Skating   Speed skating  FIN      10000m            M
# 9  1924  Chamonix     Skating   Speed skating  FIN       1500m            M
#
#   Medal
# 1  Gold
# 2  Gold
# 4  Gold
# 7  Gold
# 9  Gold

# %%
	data[(data['City']=='Nagano')&(data['Year']>1998)]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, NOC, Event, Event gender, Medal]
# Index: []

# %%
import pandas as pd 
url ='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
	data[(data['City']=='Nagano')&(data['Year']>1960)]
# Out:
#       Year    City   Sport      Discipline  NOC            Event Event gender  \
# 1620  1998  Nagano  Skiing   Alpine Skiing  AUS           slalom            W
# 1621  1998  Nagano    Luge            Luge  AUT          singles            W
# 1622  1998  Nagano  Skiing   Alpine Skiing  AUT  alpine combined            M
# 1623  1998  Nagano  Skiing   Alpine Skiing  AUT  alpine combined            M
# 1624  1998  Nagano  Skiing   Alpine Skiing  AUT         downhill            M
# ...    ...     ...     ...             ...  ...              ...          ...
# 1820  1998  Nagano  Skiing  Freestyle Ski.  USA          aerials            M
# 1821  1998  Nagano  Skiing  Freestyle Ski.  USA          aerials            W
# 1822  1998  Nagano  Skiing  Freestyle Ski.  USA           moguls            M
# 1823  1998  Nagano  Skiing       Snowboard  USA        Half-pipe            M
# 1824  1998  Nagano  Skiing       Snowboard  USA        Half-pipe            W
#
#        Medal
# 1620  Bronze
# ...

# %%
data[data['Medal']=='Gold']
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 7     1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9     1924  Chamonix     Skating   Speed skating  FIN            1500m
# ...    ...       ...         ...             ...  ...              ...
# 2301  2006     Turin      Skiing   Alpine Skiing  USA  Alpine combined
# 2302  2006     Turin      Skiing   Alpine Skiing  USA     giant slalom
# 2305  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender Medal
# 1               W  Gold
# 2               X  Gold
# 4               M  Gold
# ...

# %%
data[data['Medal']!='Silver']
# Out:
#       Year      City       Sport      Discipline  NOC                  Event  \
# 1     1924  Chamonix     Skating  Figure skating  AUT             individual
# 2     1924  Chamonix     Skating  Figure skating  AUT                  pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL               four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN             ice hockey
# 7     1924  Chamonix     Skating   Speed skating  FIN                 10000m
# ...    ...       ...         ...             ...  ...                    ...
# 2303  2006     Turin      Skiing  Freestyle Ski.  USA                 moguls
# 2304  2006     Turin      Skiing       Snowboard  USA  Giant parallel slalom
# 2305  2006     Turin      Skiing       Snowboard  USA              Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA              Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA        Snowboard Cross
#
#      Event gender   Medal
# ...

# %%
	data[(data['City']=='Nagano')&(data['Year']>1960)&(data['Medal']=='Gold')]
# Out:
#       Year    City      Sport      Discipline  NOC            Event  \
# 1623  1998  Nagano     Skiing   Alpine Skiing  AUT  alpine combined
# 1625  1998  Nagano     Skiing   Alpine Skiing  AUT     giant slalom
# 1629  1998  Nagano     Skiing   Alpine Skiing  AUT          super-G
# 1641  1998  Nagano   Biathlon        Biathlon  BUL             15km
# 1642  1998  Nagano  Bobsleigh       Bobsleigh  CAN          two-man
# ...    ...     ...        ...             ...  ...              ...
# 1815  1998  Nagano    Skating  Figure skating  USA       individual
# 1819  1998  Nagano     Skiing   Alpine Skiing  USA          super-G
# 1820  1998  Nagano     Skiing  Freestyle Ski.  USA          aerials
# 1821  1998  Nagano     Skiing  Freestyle Ski.  USA          aerials
# 1822  1998  Nagano     Skiing  Freestyle Ski.  USA           moguls
#
#      Event gender Medal
# 1623            M  Gold
# 1625            M  Gold
# 1629            M  Gold
# 1641            W  Gold
# ...

# %%
data.groupby('Score ').count()

# %%
import pandas as pd 
url ='http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
	data[(data['City']=='Turin')&(data['Year']>2004)]
# Out:
#       Year   City   Sport      Discipline  NOC            Event Event gender  \
# 2059  2006  Turin  Skiing  Freestyle Ski.  AUS          aerials            W
# 2060  2006  Turin  Skiing  Freestyle Ski.  AUS           moguls            M
# 2061  2006  Turin    Luge            Luge  AUT          doubles            X
# 2062  2006  Turin  Skiing   Alpine Skiing  AUT  Alpine combined            M
# 2063  2006  Turin  Skiing   Alpine Skiing  AUT  Alpine combined            W
# ...    ...    ...     ...             ...  ...              ...          ...
# 2306  2006  Turin  Skiing       Snowboard  USA        Half-pipe            M
# 2307  2006  Turin  Skiing       Snowboard  USA        Half-pipe            W
# 2308  2006  Turin  Skiing       Snowboard  USA        Half-pipe            W
# 2309  2006  Turin  Skiing       Snowboard  USA  Snowboard Cross            M
# 2310  2006  Turin  Skiing       Snowboard  USA  Snowboard Cross            W
#
#        Medal
# 2059  Bronze
# 2060    Gold
# ...

# %%
	data[(data['City']=='Turin')&(data['Year']>2004)&(data['Medal']=='Gold')].count()
# Out:
# Year            84
# City            84
# Sport           84
# Discipline      84
# NOC             84
# Event           84
# Event gender    84
# Medal           84
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Medal']=='Silver')].count()
# Out:
# Year            84
# City            84
# Sport           84
# Discipline      84
# NOC             84
# Event           84
# Event gender    84
# Medal           84
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Medal']=='Bronze')].count()
# Out:
# Year            84
# City            84
# Sport           84
# Discipline      84
# NOC             84
# Event           84
# Event gender    84
# Medal           84
# dtype: int64

# %%
data['Sport'].unique()
# Out:
# array(['Skating', 'Bobsleigh', 'Ice Hockey', 'Biathlon', 'Skiing',
#        'Curling', 'Luge'], dtype=object)

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Skiing')&(data['Medal']=='Gold')].count()
# Out:
# Year            38
# City            38
# Sport           38
# Discipline      38
# NOC             38
# Event           38
# Event gender    38
# Medal           38
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Skiing')&(data['Medal']=='Silver')].count()
# Out:
# Year            38
# City            38
# Sport           38
# Discipline      38
# NOC             38
# Event           38
# Event gender    38
# Medal           38
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Skiing')&(data['Medal']=='Bronze')].count()
# Out:
# Year            38
# City            38
# Sport           38
# Discipline      38
# NOC             38
# Event           38
# Event gender    38
# Medal           38
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Biathlon')&(data['Medal']=='Gold')].count()
# Out:
# Year            10
# City            10
# Sport           10
# Discipline      10
# NOC             10
# Event           10
# Event gender    10
# Medal           10
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Biathlon')&(data['Medal']=='Silver')].count()
# Out:
# Year            10
# City            10
# Sport           10
# Discipline      10
# NOC             10
# Event           10
# Event gender    10
# Medal           10
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Biathlon')&(data['Medal']=='Bronze')].count()
# Out:
# Year            10
# City            10
# Sport           10
# Discipline      10
# NOC             10
# Event           10
# Event gender    10
# Medal           10
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Ice Hockey')&(data['Medal']=='Gold')].count()
# Out:
# Year            2
# City            2
# Sport           2
# Discipline      2
# NOC             2
# Event           2
# Event gender    2
# Medal           2
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Ice Hockey')&(data['Medal']=='Silver')].count()
# Out:
# Year            2
# City            2
# Sport           2
# Discipline      2
# NOC             2
# Event           2
# Event gender    2
# Medal           2
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Ice Hockey')&(data['Medal']=='Bronze')].count()
# Out:
# Year            2
# City            2
# Sport           2
# Discipline      2
# NOC             2
# Event           2
# Event gender    2
# Medal           2
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Bobsleigh')&(data['Medal']=='Gold')].count()
# Out:
# Year            5
# City            5
# Sport           5
# Discipline      5
# NOC             5
# Event           5
# Event gender    5
# Medal           5
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Bobsleigh')&(data['Medal']=='Silver')].count()
# Out:
# Year            5
# City            5
# Sport           5
# Discipline      5
# NOC             5
# Event           5
# Event gender    5
# Medal           5
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Bobsleigh')&(data['Medal']=='Bronze')].count()
# Out:
# Year            5
# City            5
# Sport           5
# Discipline      5
# NOC             5
# Event           5
# Event gender    5
# Medal           5
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Skating')&(data['Medal']=='Gold')].count()
# Out:
# Year            24
# City            24
# Sport           24
# Discipline      24
# NOC             24
# Event           24
# Event gender    24
# Medal           24
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Skating')&(data['Medal']=='Silver')].count()
# Out:
# Year            24
# City            24
# Sport           24
# Discipline      24
# NOC             24
# Event           24
# Event gender    24
# Medal           24
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Skating')&(data['Medal']=='Bronze')].count()
# Out:
# Year            24
# City            24
# Sport           24
# Discipline      24
# NOC             24
# Event           24
# Event gender    24
# Medal           24
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Curling')&(data['Medal']=='Gold')].count()
# Out:
# Year            2
# City            2
# Sport           2
# Discipline      2
# NOC             2
# Event           2
# Event gender    2
# Medal           2
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Curling')&(data['Medal']=='Silver')].count()
# Out:
# Year            2
# City            2
# Sport           2
# Discipline      2
# NOC             2
# Event           2
# Event gender    2
# Medal           2
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Curling')&(data['Medal']=='Bronze')].count()
# Out:
# Year            2
# City            2
# Sport           2
# Discipline      2
# NOC             2
# Event           2
# Event gender    2
# Medal           2
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Luge')&(data['Medal']=='Gold')].count()
# Out:
# Year            3
# City            3
# Sport           3
# Discipline      3
# NOC             3
# Event           3
# Event gender    3
# Medal           3
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Luge')&(data['Medal']=='Silver')].count()
# Out:
# Year            3
# City            3
# Sport           3
# Discipline      3
# NOC             3
# Event           3
# Event gender    3
# Medal           3
# dtype: int64

# %%
data[(data['City']=='Turin')&(data['Year']>2004)&(data['Sport']=='Luge')&(data['Medal']=='Bronze')].count()
# Out:
# Year            3
# City            3
# Sport           3
# Discipline      3
# NOC             3
# Event           3
# Event gender    3
# Medal           3
# dtype: int64
